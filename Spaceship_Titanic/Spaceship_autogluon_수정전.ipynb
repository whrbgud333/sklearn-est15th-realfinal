# %% [markdown]
# # 스페이스쉽 타이타닉 : 최적의 오토글루온 학습 경로
#
# AutoGluon을 활용하여 스페이스쉽 타이타닉 경진대회를 위한 머신러닝 파이프라인을 구현합니다. 탐색적 데이터 분석(EDA)을 통해 얻은 특성 엔지니어링을 적용하였으며, 성능 극대화를 위해 AutoGluon의 하이퍼파라미터를 최적화했습니다.

# %%
import pandas as pd
import numpy as np
from autogluon.tabular import TabularPredictor
import os

TRAIN_PATH = "train.csv"
TEST_PATH = "test.csv"
SUBMISSION_PATH = "submission/submission_optimized.csv"
MODEL_PATH = "AutogluonModels/ag-optimized-best-quality"

print("Libraries loaded and paths set.")
# Out:
# Libraries loaded and paths set.

# %% [markdown]
# ## 1. 데이터 로드

# %%
print("Loading data...")
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)

# Combine for consistent preprocessing
train_len = len(train_df)
all_data = pd.concat([train_df, test_df], sort=False).reset_index(drop=True)

print(f"Combined shape: {all_data.shape}")
# Out:
# Loading data...
# Combined shape: (12970, 14)

# %% [markdown]
# ## 2. 특성 엔지니어링

# %%
# Spending Columns
spending_cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
all_data[spending_cols] = all_data[spending_cols].fillna(0)
all_data['TotalSpending'] = all_data[spending_cols].sum(axis=1)
print("Spending features created.")
# Out:
# Spending features created.

# %% [markdown]
# ### 승객 정보 Features
# 논리적인 규칙과 지출 습관을 바탕으로 냉동수면(CryoSleep), 나이(Age), VIP 여부, 그리고 목적지(Destination)의 결측치를 추론하여 채웁니다.

# %%
# CryoSleep Imputation
all_data.loc[(all_data['CryoSleep'].isna()) & (all_data['TotalSpending'] > 0), 'CryoSleep'] = False
all_data.loc[(all_data['CryoSleep'].isna()) & (all_data['TotalSpending'] == 0), 'CryoSleep'] = True
all_data['CryoSleep'] = all_data['CryoSleep'].astype(bool)

# Age & AgeGroup
all_data['Age'] = all_data['Age'].fillna(all_data['Age'].median())

def update_age_group(age):
    if age <= 4: return 'Baby'
    elif age <= 12: return 'Child'
    elif age <= 19: return 'Teenager'
    elif age <= 40: return 'Adult'
    elif age <= 60: return 'Middle Aged'
    else: return 'Senior'

all_data['AgeGroup'] = all_data['Age'].apply(update_age_group)

# VIP Imputation
all_data.loc[(all_data['VIP'].isna()) & (all_data['TotalSpending'] == 0), 'VIP'] = False
all_data.loc[(all_data['VIP'].isna()) & (all_data['Age'] <= 19), 'VIP'] = False
all_data['VIP'] = all_data['VIP'].fillna(False).astype(bool)

# Destination Imputation
dest_mode = all_data['Destination'].mode()[0]
all_data['Destination'] = all_data['Destination'].fillna(dest_mode)

print("Personal status features engineered.")
# Out:
# Personal status features engineered.
# C:\Users\User\AppData\Local\Temp\ipykernel_7240\3917088119.py:22: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   all_data['VIP'] = all_data['VIP'].fillna(False).astype(bool)

# %% [markdown]
# ### Group and Family Features
# 그룹 ID와 성씨(Surname)를 추출하여, 가족이나 그룹 내의 관계를 바탕으로 결측치를 정교하게 추론(Imputation)하는 데 활용합니다

# %%
# 1. Group & GroupSize
all_data['Group'] = all_data['PassengerId'].str.split('_').str[0]
group_sizes = all_data.groupby('Group').size()
all_data['GroupSize'] = all_data['Group'].map(group_sizes)

# 2. Surname & FamilySize
all_data['Surname'] = all_data['Name'].str.split().str[-1]
# Fill Surname within Group if possible
all_data['Surname'] = all_data.groupby('Group')['Surname'].ffill()
all_data['Surname'] = all_data.groupby('Group')['Surname'].bfill()

# Map FamilySize
family_counts = all_data['Surname'].value_counts()
all_data['FamilySize'] = all_data['Surname'].map(family_counts)
all_data.loc[all_data['Surname'].isna(), 'FamilySize'] = 1 # Default for unknown

# 3. HomePlanet Imputation
all_data['HomePlanet'] = all_data.groupby('Group')['HomePlanet'].ffill()
all_data['HomePlanet'] = all_data.groupby('Group')['HomePlanet'].bfill()
# Map based on Surname if still missing
home_map = all_data.dropna(subset=['HomePlanet']).groupby('Surname')['HomePlanet'].agg(lambda x: x.mode()[0] if not x.mode().empty else np.nan)
all_data['HomePlanet'] = all_data['HomePlanet'].fillna(all_data['Surname'].map(home_map))
all_data['HomePlanet'] = all_data['HomePlanet'].fillna(all_data['HomePlanet'].mode()[0])

print("Group and family features engineered.")
# Out:
# Group and family features engineered.

# %% [markdown]
# ### 객식(Cabin) Features
# 객실 정보 세분화 및 복원: Cabin 데이터를 Deck(데크), Num(번호), Side(좌우)로 분리하고, 그룹 내 다른 구성원의 정보를 활용하여 누락된 객실 값을 정교하게 채웁니다

# %%
# Split Cabin
all_data[['Deck', 'Num', 'Side']] = all_data['Cabin'].str.split('/', expand=True)

# Fill within Group
for col in ['Deck', 'Num', 'Side']:
    all_data[col] = all_data.groupby('Group')[col].ffill()
    all_data[col] = all_data.groupby('Group')[col].bfill()

# Process Num (convert to numeric)
if all_data['Num'].isna().sum() > 0:
    all_data['Num'] = pd.to_numeric(all_data['Num'], errors='coerce')
    all_data['Num'] = all_data['Num'].fillna(all_data['Num'].median())

print("Cabin features engineered.")
# Out:
# Cabin features engineered.

# %% [markdown]
# ## 3. 데이터 전처리
# 모델링을 위한 데이터 준비: 과적합(Overfitting)을 유발할 수 있는 고유 식별값 및 중복 열(PassengerId, Name, Cabin, Surname, Group)을 제거하고, 데이터를 다시 학습용(Train)과 테스트용(Test)으로 분리합니다

# %%
cols_to_drop = ['PassengerId', 'Name', 'Cabin', 'Surname', 'Group']

train_final = all_data.iloc[:train_len].copy().drop(columns=cols_to_drop)
test_final = all_data.iloc[train_len:].copy().drop(columns=cols_to_drop)

# Ensure target is dropped from test if present
if 'Transported' in test_final.columns:
    test_final = test_final.drop(columns=['Transported'])

# Train target formatting
label = 'Transported'
train_final[label] = train_final[label].astype(bool)

print(f"Final Train Shape: {train_final.shape}")
print(f"Final Test Shape: {test_final.shape}")
print(f"Features: {list(train_final.columns)}")
# Out:
# Final Train Shape: (8693, 18)
# Final Test Shape: (4277, 17)
# Features: ['HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Transported', 'TotalSpending', 'AgeGroup', 'GroupSize', 'FamilySize', 'Deck', 'Num', 'Side']

# %% [markdown]
# ## 4. AutoGluon 모델 학습
# 모델 최적화 및 학습: 최상의 앙상블 성능을 위해 best_quality 프리셋을 사용하며, 1시간의 제한 시간, 8겹의 배깅(Bagging), 그리고 2단계 스태킹(Stacking)을 적용합니다. 또한, 과적합을 방지하기 위해 CatBoost 모델의 깊이를 6으로 제한합니다.

# %% [markdown]
# CatBoost를 단일 알고리즘으로 사용하되, 8-폴드 배깅(Bagging)과 2단계 스태킹(Stacking) 기술을 적용한 CatBoost 전용 앙상블 모델입니다.<br>best_quality로 1시간 학습 : WeightedEnsemble_L2가 최고 모델로 선정되었으며, 0.8227점이 나왔습니다.

# %%
print("Starting AutoGluon Training...")

hyperparameters = {
    'CAT': {'depth': 6},
}

predictor = TabularPredictor(
    label=label,
    eval_metric='accuracy',
    path=MODEL_PATH,
    problem_type='binary'
).fit(
    train_data=train_final,
    presets='best_quality',
    time_limit=3600, # 1 hour
    num_bag_folds=8,
    num_stack_levels=2,
    hyperparameters=hyperparameters,
)
# 모델별 성적표(리더보드) 출력
print("\n=== [결과 리더보드] ===")
lb = predictor.leaderboard(extra_info=True)
display(lb[['model', 'score_val', 'pred_time_val', 'fit_time']])

# 최고 모델의 이름과 점수 가져오기
# get_model_best() 대신 아래 두 가지 중 하나를 사용합니다.
best_model_name = predictor.model_best 
best_score = lb.loc[lb['model'] == best_model_name, 'score_val'].values[0]

print(f"\n최고 모델: {best_model_name}")
print(f"내부 검증 정확도(Score_Val): {best_score:.4f}")
print("Training Complete.")
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/ag-optimized-best-quality"
# Verbosity: 2 (Standard Logging)
# Starting AutoGluon Training...
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          16
# Pytorch Version:    2.9.1+cpu
# CUDA Version:       CUDA is not available
# Memory Avail:       10.75 GB / 31.72 GB (33.9%)
# Disk Space Avail:   250.37 GB / 476.83 GB (52.5%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=2, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2026-02-13 01:58:49,296	INFO worker.py:2014 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# c:\Users\User\miniconda3\envs\DS\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 		Context path: "c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\AutogluonModels\ag-optimized-best-quality\ds_sub_fit\sub_fit_ho"
# (_dystack pid=21564) Running DyStack sub-fit ...
# (_dystack pid=21564) Beginning AutoGluon training ... Time limit = 894s
# (_dystack pid=21564) AutoGluon will save models to "c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\AutogluonModels\ag-optimized-best-quality\ds_sub_fit\sub_fit_ho"
# (_dystack pid=21564) Train Data Rows:    7727
# (_dystack pid=21564) Train Data Columns: 17
# (_dystack pid=21564) Label Column:       Transported
# (_dystack pid=21564) Problem Type:       binary
# (_dystack pid=21564) Preprocessing data ...
# (_dystack pid=21564) Selected class <--> label mapping:  class 1 = True, class 0 = False
# (_dystack pid=21564) Using Feature Generators to preprocess the data ...
# (_dystack pid=21564) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=21564) 	Available Memory:                    9396.31 MB
# (_dystack pid=21564) 	Train Data (Original)  Memory Usage: 2.88 MB (0.0% of available memory)
# (_dystack pid=21564) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=21564) 	Stage 1 Generators:
# (_dystack pid=21564) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=21564) 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=21564) 	Stage 2 Generators:
# (_dystack pid=21564) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=21564) 	Stage 3 Generators:
# (_dystack pid=21564) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=21564) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=21564) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=21564) 	Stage 4 Generators:
# (_dystack pid=21564) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=21564) 	Stage 5 Generators:
# (_dystack pid=21564) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=21564) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=21564) 		('bool', [])   : 2 | ['CryoSleep', 'VIP']
# (_dystack pid=21564) 		('float', [])  : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# (_dystack pid=21564) 		('int', [])    : 1 | ['GroupSize']
# (_dystack pid=21564) 		('object', []) : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# (_dystack pid=21564) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=21564) 		('category', [])  : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# (_dystack pid=21564) 		('float', [])     : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# (_dystack pid=21564) 		('int', [])       : 1 | ['GroupSize']
# (_dystack pid=21564) 		('int', ['bool']) : 2 | ['CryoSleep', 'VIP']
# (_dystack pid=21564) 	0.1s = Fit runtime
# (_dystack pid=21564) 	17 features in original data used to generate 17 features in processed data.
# (_dystack pid=21564) 	Train Data (Processed) Memory Usage: 0.64 MB (0.0% of available memory)
# (_dystack pid=21564) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=21564) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=21564) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=21564) User-specified model hyperparameters to be fit:
# (_dystack pid=21564) {
# (_dystack pid=21564) 	'CAT': [{'depth': 6}],
# (_dystack pid=21564) }
# (_dystack pid=21564) AutoGluon will fit 3 stack levels (L1 to L3) ...
# (_dystack pid=21564) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=21564) Fitting model: CatBoost_BAG_L1 ... Training model for up to 397.04s of the 893.56s of remaining time.
# (_dystack pid=21564) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.16%)
# (_dystack pid=21564) 	0.8204	 = Validation score   (accuracy)
# (_dystack pid=21564) 	58.43s	 = Training   runtime
# (_dystack pid=21564) 	0.05s	 = Validation runtime
# (_dystack pid=21564) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 825.71s of remaining time.
# (_dystack pid=21564) 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/9.4 GB
# (_dystack pid=21564) 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# (_dystack pid=21564) 	0.8204	 = Validation score   (accuracy)
# (_dystack pid=21564) 	0.01s	 = Training   runtime
# (_dystack pid=21564) 	0.0s	 = Validation runtime
# (_dystack pid=21564) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=21564) Fitting model: CatBoost_BAG_L2 ... Training model for up to 550.31s of the 825.68s of remaining time.
# (_dystack pid=21564) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.19%)
# (_dystack pid=21564) 	0.8214	 = Validation score   (accuracy)
# (_dystack pid=21564) 	36.02s	 = Training   runtime
# (_dystack pid=21564) 	0.04s	 = Validation runtime
# (_dystack pid=21564) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 785.48s of remaining time.
# (_dystack pid=21564) 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/9.4 GB
# (_dystack pid=21564) 	Ensemble Weights: {'CatBoost_BAG_L2': 1.0}
# (_dystack pid=21564) 	0.8214	 = Validation score   (accuracy)
# (_dystack pid=21564) 	0.0s	 = Training   runtime
# (_dystack pid=21564) 	0.0s	 = Validation runtime
# (_dystack pid=21564) Fitting 1 L3 models, fit_strategy="sequential" ...
# (_dystack pid=21564) Fitting model: CatBoost_BAG_L3 ... Training model for up to 785.47s of the 785.47s of remaining time.
# (_dystack pid=21564) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.19%)
# (_dystack pid=21564) 	0.8248	 = Validation score   (accuracy)
# (_dystack pid=21564) 	75.65s	 = Training   runtime
# (_dystack pid=21564) 	0.05s	 = Validation runtime
# (_dystack pid=21564) Fitting model: WeightedEnsemble_L4 ... Training model for up to 360.00s of the 704.81s of remaining time.
# (_dystack pid=21564) 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/9.4 GB
# (_dystack pid=21564) 	Ensemble Weights: {'CatBoost_BAG_L3': 1.0}
# (_dystack pid=21564) 	0.8248	 = Validation score   (accuracy)
# (_dystack pid=21564) 	0.05s	 = Training   runtime
# (_dystack pid=21564) 	0.0s	 = Validation runtime
# (_dystack pid=21564) AutoGluon training complete, total runtime = 188.9s ... Best model: WeightedEnsemble_L4 | Estimated inference throughput: 6756.6 rows/s (966 batch size)
# (_dystack pid=21564) Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (7727 rows).
# (_dystack pid=21564) 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# (_dystack pid=21564) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\AutogluonModels\ag-optimized-best-quality\ds_sub_fit\sub_fit_ho")
# (_dystack pid=21564) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      CatBoost_BAG_L1       0.806418   0.820370    accuracy        0.936741       0.049077   58.433268                 0.936741                0.049077          58.433268            1       True          1
# 1  WeightedEnsemble_L2       0.806418   0.820370    accuracy        0.983722       0.049077   58.441943                 0.046982                0.000000           0.008676            2       True          2
# 2      CatBoost_BAG_L3       0.806418   0.824770    accuracy        1.500677       0.142846  170.094630                 0.332052                0.053782          75.645918            3       True          5
# 3  WeightedEnsemble_L4       0.806418   0.824770    accuracy        1.516388       0.143846  170.146200                 0.015711                0.000999           0.051570            4       True          6
# 4      CatBoost_BAG_L2       0.805383   0.821405    accuracy        1.168624       0.089065   94.448712                 0.231884                0.039988          36.015444            2       True          3
# 5  WeightedEnsemble_L3       0.805383   0.821405    accuracy        1.257022       0.089065   94.453338                 0.088397                0.000000           0.004626            3       True          4
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	200s	 = DyStack   runtime |	3400s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 3400s
# AutoGluon will save models to "c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\AutogluonModels\ag-optimized-best-quality"
# Train Data Rows:    8693
# Train Data Columns: 17
# Label Column:       Transported
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = True, class 0 = False
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10083.89 MB
# 	Train Data (Original)  Memory Usage: 3.24 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])   : 2 | ['CryoSleep', 'VIP']
# 		('float', [])  : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# 		('int', [])    : 1 | ['GroupSize']
# 		('object', []) : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# 		('float', [])     : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# 		('int', [])       : 1 | ['GroupSize']
# 		('int', ['bool']) : 2 | ['CryoSleep', 'VIP']
# 	0.1s = Fit runtime
# 	17 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.72 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'CAT': [{'depth': 6}],
# }
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3400.24s of the 3400.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=3.98%)
# 	0.8227	 = Validation score   (accuracy)
# 	71.76s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 3317.66s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/9.6 GB
# 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# 	0.8227	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 82.8s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 13518.7 rows/s (1087 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (8693 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\AutogluonModels\ag-optimized-best-quality")
# === [결과 리더보드] ===
#                  model  score_val  pred_time_val   fit_time
# 0      CatBoost_BAG_L1   0.822731       0.080316  71.760566
# 1  WeightedEnsemble_L2   0.822731       0.081048  71.774350
# 최고 모델: WeightedEnsemble_L2
# 내부 검증 정확도(Score_Val): 0.8227
# Training Complete.

# %% [markdown]
# 모델을 따로 지정하지 않고, excluded_model_types=[] 설정을 통해 AutoGluon이 모든 모델을 사용해서 데이터의 특성에 맞춰 최적의 모델 조합을 스스로 선택하여 강력한 멀티레이어 스태킹(Multi-layer Stacking) 앙상블을 구축합니다.

# %% [markdown]
# 최고 모델은 WeightedEnsemble_L4로 0.8242점이 나왔습니다.

# %%
print("Starting AutoGluon Training...")

predictor = TabularPredictor(
    label=label,
    eval_metric='accuracy',
    path='ag_models/spaceship_autogluon_best_quality_v1',
    problem_type='binary'
).fit(
    train_data=train_final,
    presets='best_quality',      # 고품질 앙상블 활성화
    time_limit=3600,             # 1시간 동안 충분히 모델들을 섞음
    num_bag_folds=8,             # 안정적인 점수를 위한 8겹 배깅
    num_stack_levels=2,          # 모델들의 예측치를 다시 학습하는 2단계 스태킹
    excluded_model_types=[], # 모든 모델 사용
)

# 모델별 성적표(리더보드) 출력
print("\n=== [결과 리더보드] ===")
lb = predictor.leaderboard(extra_info=True)
display(lb[['model', 'score_val', 'pred_time_val', 'fit_time']])

# 최고 모델의 이름과 점수 가져오기
# get_model_best() 대신 아래 두 가지 중 하나를 사용합니다.
best_model_name = predictor.model_best 
best_score = lb.loc[lb['model'] == best_model_name, 'score_val'].values[0]

print(f"\n최고 모델: {best_model_name}")
print(f"내부 검증 정확도(Score_Val): {best_score:.4f}")
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_models/spaceship_autogluon_best_quality_v1"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          16
# Pytorch Version:    2.9.1+cpu
# CUDA Version:       CUDA is not available
# Memory Avail:       9.82 GB / 31.72 GB (30.9%)
# Disk Space Avail:   250.37 GB / 476.83 GB (52.5%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=2, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 		Context path: "c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\ag_models\spaceship_autogluon_best_quality_v1\ds_sub_fit\sub_fit_ho"
# Starting AutoGluon Training...
# Leaderboard on holdout data (DyStack):
#                         model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   NeuralNetTorch_r79_BAG_L2       0.818841   0.825547    accuracy        7.983480       3.652373  362.418793                 0.453263                0.294064          36.129321            2       True         28
# 1      NeuralNetFastAI_BAG_L2       0.815735   0.823606    accuracy        8.197348       3.677016  364.045872                 0.667131                0.318707          37.756401            2       True         23
# 2           LightGBMXT_BAG_L2       0.814700   0.826064    accuracy        7.811385       3.476166  330.037652                 0.281168                0.117857           3.748180            2       True         16
# 3             CatBoost_BAG_L2       0.813665   0.832018    accuracy        7.734744       3.432242  391.966392                 0.204527                0.073932          65.676920            2       True         20
# 4       ExtraTreesGini_BAG_L3       0.813665   0.826841    accuracy       12.289034       6.967372  595.809892                 0.183756                0.393179           1.132864            3       True         35
# 5     RandomForestEntr_BAG_L3       0.813665   0.828394    accuracy       12.291316       6.902522  596.377180                 0.186038                0.328328           1.700151            3       True         33
# 6             LightGBM_BAG_L3       0.811594   0.833441    accuracy       12.381056       6.667359  598.148027                 0.275778                0.093165           3.470999            3       True         31
# 7        CatBoost_r177_BAG_L1       0.810559   0.823864    accuracy        1.162248       0.063002   10.218466                 1.162248                0.063002          10.218466            1       True         12
# 8         WeightedEnsemble_L2       0.810559   0.823864    accuracy        1.186421       0.063002   10.370304                 0.024173                0.000000           0.151838            2       True         15
# 9        CatBoost_r177_BAG_L2       0.810559   0.832406    accuracy        7.812042       3.439450  343.640995                 0.281825                0.081141          17.351523            2       True         27
# 10        WeightedEnsemble_L3       0.810559   0.832406    accuracy        7.825917       3.446747  343.928292                 0.013875                0.007297           0.287297            3       True         29
# 11      ExtraTreesEntr_BAG_L3       0.809524   0.826712    accuracy       12.276873       6.908108  595.803443                 0.171595                0.333915           1.126415            3       True         36
# 12       LightGBMLarge_BAG_L1       0.808489   0.811699    accuracy        0.495264       0.217727    6.368782                 0.495264                0.217727           6.368782            1       True         11
# 13    RandomForestGini_BAG_L3       0.808489   0.826582    accuracy       12.335092       6.941519  596.414816                 0.229814                0.367326           1.737787            3       True         32
# 14            CatBoost_BAG_L3       0.808489   0.835900    accuracy       12.336934       6.640825  626.913726                 0.231656                0.066632          32.236698            3       True         34
# 15        WeightedEnsemble_L4       0.808489   0.835900    accuracy       12.361006       6.644009  627.544271                 0.024072                0.003184           0.630544            4       True         40
# 16      NeuralNetTorch_BAG_L3       0.808489   0.831241    accuracy       12.642792       6.838823  630.950083                 0.537513                0.264629          36.273055            3       True         39
# 17             XGBoost_BAG_L3       0.808489   0.832535    accuracy       12.816830       6.755879  602.439979                 0.711552                0.181685           7.762950            3       True         38
# 18            LightGBM_BAG_L1       0.807453   0.816617    accuracy        0.327858       0.164680    4.078777                 0.327858                0.164680           4.078777            1       True          2
# 19       LightGBMLarge_BAG_L2       0.807453   0.827747    accuracy        8.016889       3.640034  342.028187                 0.486671                0.281725          15.738715            2       True         26
# 20    RandomForestEntr_BAG_L1       0.806418   0.800828    accuracy        0.221931       0.345147    1.456895                 0.221931                0.345147           1.456895            1       True          4
# 21             XGBoost_BAG_L1       0.806418   0.813770    accuracy        0.689920       0.129937    3.321878                 0.689920                0.129937           3.321878            1       True          9
# 22            CatBoost_BAG_L1       0.806418   0.820370    accuracy        0.749964       0.083162   81.465555                 0.749964                0.083162          81.465555            1       True          5
# 23      ExtraTreesEntr_BAG_L2       0.806418   0.827229    accuracy        7.689928       3.722943  327.301826                 0.159711                0.364634           1.012355            2       True         22
# 24      ExtraTreesEntr_BAG_L1       0.805383   0.798758    accuracy        0.221942       0.334795    1.005625                 0.221942                0.334795           1.005625            1       True          7
# 25    RandomForestEntr_BAG_L2       0.805383   0.826453    accuracy        7.680482       3.712236  328.579715                 0.150265                0.353927           2.290243            2       True         19
# 26      ExtraTreesGini_BAG_L2       0.805383   0.822700    accuracy        7.697708       3.684976  327.407761                 0.167491                0.326667           1.118289            2       True         21
# 27             XGBoost_BAG_L2       0.805383   0.829688    accuracy        8.157696       3.561660  331.813033                 0.627479                0.203350           5.523561            2       True         24
# 28          LightGBMXT_BAG_L3       0.805383   0.833441    accuracy       12.370117       6.654744  597.312706                 0.264839                0.080550           2.635677            3       True         30
# 29     NeuralNetFastAI_BAG_L3       0.805383   0.832665    accuracy       12.802978       6.902717  632.417161                 0.697700                0.328524          37.740132            3       True         37
# 30    RandomForestGini_BAG_L1       0.804348   0.801217    accuracy        0.355652       0.490732    1.938572                 0.355652                0.490732           1.938572            1       True          3
# 31          LightGBMXT_BAG_L1       0.804348   0.823735    accuracy        0.575394       0.253023    4.411351                 0.575394                0.253023           4.411351            1       True          1
# 32            LightGBM_BAG_L2       0.804348   0.831888    accuracy        7.808254       3.493293  330.902360                 0.278037                0.134984           4.612888            2       True         17
# 33       LightGBM_r131_BAG_L1       0.803313   0.817394    accuracy        0.385326       0.268263    5.307771                 0.385326                0.268263           5.307771            1       True         14
# 34    RandomForestGini_BAG_L2       0.801242   0.828006    accuracy        7.730211       3.780141  328.694538                 0.199993                0.421832           2.405066            2       True         18
# 35      ExtraTreesGini_BAG_L1       0.800207   0.802381    accuracy        0.362685       0.383579    0.915718                 0.362685                0.383579           0.915718            1       True          6
# 36      NeuralNetTorch_BAG_L2       0.799172   0.824511    accuracy        8.147717       3.601374  401.313566                 0.617500                0.243065          75.024094            2       True         25
# 37     NeuralNetFastAI_BAG_L1       0.796066   0.818429    accuracy        1.471062       0.294982   31.786478                 1.471062                0.294982          31.786478            1       True          8
# 38      NeuralNetTorch_BAG_L1       0.790890   0.803417    accuracy        0.597074       0.268231   88.832284                 0.597074                0.268231          88.832284            1       True         10
# 39  NeuralNetTorch_r79_BAG_L1       0.784679   0.802770    accuracy        0.409163       0.278775   91.550102                 0.409163                0.278775          91.550102            1       True         13
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	926s	 = DyStack   runtime |	2674s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 2674s
# AutoGluon will save models to "c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\ag_models\spaceship_autogluon_best_quality_v1"
# Train Data Rows:    8693
# Train Data Columns: 17
# Label Column:       Transported
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = True, class 0 = False
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9751.90 MB
# 	Train Data (Original)  Memory Usage: 3.24 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])   : 2 | ['CryoSleep', 'VIP']
# 		('float', [])  : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# 		('int', [])    : 1 | ['GroupSize']
# 		('object', []) : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# 		('float', [])     : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# 		('int', [])       : 1 | ['GroupSize']
# 		('int', ['bool']) : 2 | ['CryoSleep', 'VIP']
# 	0.1s = Fit runtime
# 	17 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.72 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Excluded models: [] (Specified by `excluded_model_types`)
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2674.31s of the 2674.30s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.23%)
# 	0.8201	 = Validation score   (accuracy)
# 	4.56s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2663.47s of the 2663.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.23%)
# 	0.8171	 = Validation score   (accuracy)
# 	4.54s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2652.98s of the 2652.97s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/9.3 GB
# 	0.8039	 = Validation score   (accuracy)
# 	1.56s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2650.89s of the 2650.88s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/9.8 GB
# 	0.801	 = Validation score   (accuracy)
# 	1.43s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2648.91s of the 2648.90s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.01%)
# 	0.8227	 = Validation score   (accuracy)
# 	71.29s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2569.88s of the 2569.87s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/9.7 GB
# 	0.8018	 = Validation score   (accuracy)
# 	1.19s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2567.98s of the 2567.97s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/9.8 GB
# 	0.804	 = Validation score   (accuracy)
# 	1.01s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2566.35s of the 2566.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.8202	 = Validation score   (accuracy)
# 	36.08s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2523.71s of the 2523.70s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.25%)
# 	0.8186	 = Validation score   (accuracy)
# 	3.94s	 = Training   runtime
# 	0.86s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2513.88s of the 2513.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.8028	 = Validation score   (accuracy)
# 	86.33s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2422.43s of the 2422.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.86%)
# 	0.813	 = Validation score   (accuracy)
# 	5.81s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2411.27s of the 2411.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.24%)
# 	0.8242	 = Validation score   (accuracy)
# 	12.71s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2393.41s of the 2393.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.8018	 = Validation score   (accuracy)
# 	122.97s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2264.66s of the 2264.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.36%)
# 	0.8181	 = Validation score   (accuracy)
# 	6.88s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2251.86s of the 2251.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.8173	 = Validation score   (accuracy)
# 	107.53s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2138.34s of the 2138.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.53%)
# 	0.822	 = Validation score   (accuracy)
# 	85.2s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 2046.27s of the 2046.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.13%)
# 	0.8143	 = Validation score   (accuracy)
# 	6.54s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 2032.89s of the 2032.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.8055	 = Validation score   (accuracy)
# 	153.35s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 1872.46s of the 1872.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.65%)
# 	0.8131	 = Validation score   (accuracy)
# 	7.41s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 1860.02s of the 1860.00s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/10.2 GB
# 	0.8047	 = Validation score   (accuracy)
# 	1.02s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 1858.52s of the 1858.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=3.71%)
# 	0.8187	 = Validation score   (accuracy)
# 	52.0s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 1801.59s of the 1801.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.817	 = Validation score   (accuracy)
# 	24.9s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 1770.23s of the 1770.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=5.39%)
# 	0.8214	 = Validation score   (accuracy)
# 	35.95s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 1725.86s of the 1725.85s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/10.4 GB
# 	0.8024	 = Validation score   (accuracy)
# 	2.39s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 1722.91s of the 1722.90s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.72%)
# 	0.817	 = Validation score   (accuracy)
# 	6.54s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 1710.14s of the 1710.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.8148	 = Validation score   (accuracy)
# 	75.45s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 1629.40s of the 1629.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.20%)
# 	0.8185	 = Validation score   (accuracy)
# 	4.62s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 1617.58s of the 1617.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.8055	 = Validation score   (accuracy)
# 	268.45s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 1342.39s of the 1342.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.55%)
# 	0.8174	 = Validation score   (accuracy)
# 	3.31s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 1335.96s of the 1335.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	0.8026	 = Validation score   (accuracy)
# 	300.67s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 1031.38s of the 1031.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=3.76%)
# 	0.819	 = Validation score   (accuracy)
# 	49.27s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 978.62s of the 978.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	0.815	 = Validation score   (accuracy)
# 	93.9s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 881.29s of the 881.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.30%)
# 	0.8163	 = Validation score   (accuracy)
# 	3.64s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 870.36s of the 870.35s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/9.5 GB
# 	0.8094	 = Validation score   (accuracy)
# 	1.93s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 867.86s of the 867.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=3.69%)
# 	0.8227	 = Validation score   (accuracy)
# 	82.28s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 779.03s of the 779.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	0.8185	 = Validation score   (accuracy)
# 	71.15s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 701.95s of the 701.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.786	 = Validation score   (accuracy)
# 	99.0s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 595.68s of the 595.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=2.17%)
# 	0.8118	 = Validation score   (accuracy)
# 	10.03s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 580.13s of the 580.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.12%)
# 	0.8078	 = Validation score   (accuracy)
# 	30.69s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 543.93s of the 543.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=7.20%)
# 	0.8192	 = Validation score   (accuracy)
# 	71.33s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 465.54s of the 465.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# 	0.8072	 = Validation score   (accuracy)
# 	28.76s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 430.50s of the 430.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.35%)
# 	0.8117	 = Validation score   (accuracy)
# 	13.48s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 409.25s of the 409.24s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/8.1 GB
# 	0.8034	 = Validation score   (accuracy)
# 	2.13s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 406.62s of the 406.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.74%)
# 	0.8233	 = Validation score   (accuracy)
# 	73.96s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 326.90s of the 326.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# 	0.8153	 = Validation score   (accuracy)
# 	63.83s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 256.60s of the 256.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.8061	 = Validation score   (accuracy)
# 	85.49s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 165.49s of the 165.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.47%)
# 	0.8111	 = Validation score   (accuracy)
# 	6.09s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 155.06s of the 155.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.21%)
# 	0.8161	 = Validation score   (accuracy)
# 	3.04s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 147.64s of the 147.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	0.7935	 = Validation score   (accuracy)
# 	118.41s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 24.46s of the 24.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=5.17%)
# 	0.8108	 = Validation score   (accuracy)
# 	19.58s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the -2.63s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/8.6 GB
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 1.0}
# 	0.8242	 = Validation score   (accuracy)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2677.43s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 17601.8 rows/s (1087 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (8693 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\User\Desktop\Github\sklearn-est15th-realfinal\Spaceship_Titanic\ag_models\spaceship_autogluon_best_quality_v1")
# === [결과 리더보드] ===
#                           model  score_val  pred_time_val    fit_time
# 0          CatBoost_r177_BAG_L1   0.824226       0.061593   12.714505
# 1           WeightedEnsemble_L2   0.824226       0.062889   13.065895
# 2          CatBoost_r167_BAG_L1   0.823306       0.057932   73.957142
# 3               CatBoost_BAG_L1   0.822731       0.071264   71.294309
# 4           CatBoost_r69_BAG_L1   0.822731       0.086545   82.277463
# 5            CatBoost_r9_BAG_L1   0.822041       0.078792   85.204605
# 6           CatBoost_r13_BAG_L1   0.821351       0.062963   35.949803
# 7        NeuralNetFastAI_BAG_L1   0.820200       0.310112   36.078061
# 8             LightGBMXT_BAG_L1   0.820085       0.242966    4.557313
# 9           CatBoost_r70_BAG_L1   0.819165       0.109517   71.328536
# 10          CatBoost_r50_BAG_L1   0.819050       0.082145   49.268504
# 11         CatBoost_r137_BAG_L1   0.818705       0.067892   52.001052
# 12               XGBoost_BAG_L1   0.818590       0.858043    3.940618
# 13  NeuralNetFastAI_r103_BAG_L1   0.818475       0.427210   71.147629
# 14           XGBoost_r89_BAG_L1   0.818475       1.096445    4.615076
# 15         LightGBM_r131_BAG_L1   0.818130       0.463163    6.875027
# 16         LightGBM_r130_BAG_L1   0.817439       0.113697    3.309726
# 17  NeuralNetFastAI_r191_BAG_L1   0.817324       0.585307  107.532897
# 18              LightGBM_BAG_L1   0.817094       0.174728    4.536127
# 19  NeuralNetFastAI_r102_BAG_L1   0.816979       0.331258   24.904967
# 20         LightGBM_r188_BAG_L1   0.816979       0.351034    6.536380
# 21          XGBoost_r194_BAG_L1   0.816289       0.129058    3.641982
# 22          LightGBM_r15_BAG_L1   0.816059       0.185948    3.041536
# 23   NeuralNetFastAI_r95_BAG_L1   0.815254       0.488201   63.834656
# 24   NeuralNetFastAI_r11_BAG_L1   0.815024       0.926801   93.901902
# 25  NeuralNetFastAI_r145_BAG_L1   0.814794       0.747312   75.451607
# 26          LightGBM_r96_BAG_L1   0.814333       0.466827    6.544591
# 27           XGBoost_r33_BAG_L1   0.813068       0.851582    7.408378
# 28         LightGBMLarge_BAG_L1   0.812953       0.143607    5.810352
# 29         LightGBM_r161_BAG_L1   0.811803       0.214476   10.030959
# 30         LightGBM_r196_BAG_L1   0.811688       0.691876   13.476882
# 31           XGBoost_r98_BAG_L1   0.811112       0.200826    6.087744
# 32          CatBoost_r86_BAG_L1   0.810767       0.091927   19.581218
# 33       ExtraTrees_r172_BAG_L1   0.809387       0.465396    1.925775
# 34  NeuralNetFastAI_r143_BAG_L1   0.807776       0.250280   30.687684
# 35  NeuralNetFastAI_r156_BAG_L1   0.807201       0.249479   28.759064
# 36    NeuralNetTorch_r41_BAG_L1   0.806051       0.168416   85.494987
# 37    NeuralNetTorch_r22_BAG_L1   0.805476       0.296606  153.354795
# 38    NeuralNetTorch_r30_BAG_L1   0.805476       0.429319  268.450722
# 39        ExtraTrees_r42_BAG_L1   0.804670       0.374198    1.019114
# 40        ExtraTreesEntr_BAG_L1   0.803980       0.457521    1.009423
# 41      RandomForestGini_BAG_L1   0.803865       0.417642    1.559378
# 42      RandomForest_r39_BAG_L1   0.803405       0.380268    2.134588
# 43        NeuralNetTorch_BAG_L1   0.802830       0.251242   86.325169
# 44    NeuralNetTorch_r86_BAG_L1   0.802600       0.503969  300.668324
# 45     RandomForest_r195_BAG_L1   0.802370       0.453059    2.387301
# 46    NeuralNetTorch_r79_BAG_L1   0.801795       0.252529  122.968440
# 47        ExtraTreesGini_BAG_L1   0.801795       0.538740    1.193713
# 48      RandomForestEntr_BAG_L1   0.800989       0.429334    1.427815
# 49   NeuralNetTorch_r158_BAG_L1   0.793512       0.344876  118.410551
# 50    NeuralNetTorch_r14_BAG_L1   0.786035       0.219782   99.001686
# 최고 모델: WeightedEnsemble_L2
# 내부 검증 정확도(Score_Val): 0.8242

# %% [markdown]
# ### 모델 학습 결과 요약 및 성능 평가

# %%
print(predictor.fit_summary())
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          CatBoost_r177_BAG_L1   0.824226    accuracy       0.061593   12.714505                0.061593          12.714505            1       True         12
# 1           WeightedEnsemble_L2   0.824226    accuracy       0.062889   13.065895                0.001296           0.351390            2       True         51
# 2          CatBoost_r167_BAG_L1   0.823306    accuracy       0.057932   73.957142                0.057932          73.957142            1       True         44
# 3               CatBoost_BAG_L1   0.822731    accuracy       0.071264   71.294309                0.071264          71.294309            1       True          5
# 4           CatBoost_r69_BAG_L1   0.822731    accuracy       0.086545   82.277463                0.086545          82.277463            1       True         35
# 5            CatBoost_r9_BAG_L1   0.822041    accuracy       0.078792   85.204605                0.078792          85.204605            1       True         16
# 6           CatBoost_r13_BAG_L1   0.821351    accuracy       0.062963   35.949803                0.062963          35.949803            1       True         23
# 7        NeuralNetFastAI_BAG_L1   0.820200    accuracy       0.310112   36.078061                0.310112          36.078061            1       True          8
# 8             LightGBMXT_BAG_L1   0.820085    accuracy       0.242966    4.557313                0.242966           4.557313            1       True          1
# 9           CatBoost_r70_BAG_L1   0.819165    accuracy       0.109517   71.328536                0.109517          71.328536            1       True         40
# 10          CatBoost_r50_BAG_L1   0.819050    accuracy       0.082145   49.268504                0.082145          49.268504            1       True         31
# 11         CatBoost_r137_BAG_L1   0.818705    accuracy       0.067892   52.001052                0.067892          52.001052            1       True         21
# 12               XGBoost_BAG_L1   0.818590    accuracy       0.858043    3.940618                0.858043           3.940618            1       True          9
# 13  NeuralNetFastAI_r103_BAG_L1   0.818475    accuracy       0.427210   71.147629                0.427210          71.147629            1       True         36
# 14           XGBoost_r89_BAG_L1   0.818475    accuracy       1.096445    4.615076                1.096445           4.615076            1       True         27
# 15         LightGBM_r131_BAG_L1   0.818130    accuracy       0.463163    6.875027                0.463163           6.875027            1       True         14
# 16         LightGBM_r130_BAG_L1   0.817439    accuracy       0.113697    3.309726                0.113697           3.309726            1       True         29
# 17  NeuralNetFastAI_r191_BAG_L1   0.817324    accuracy       0.585307  107.532897                0.585307         107.532897            1       True         15
# 18              LightGBM_BAG_L1   0.817094    accuracy       0.174728    4.536127                0.174728           4.536127            1       True          2
# 19  NeuralNetFastAI_r102_BAG_L1   0.816979    accuracy       0.331258   24.904967                0.331258          24.904967            1       True         22
# 20         LightGBM_r188_BAG_L1   0.816979    accuracy       0.351034    6.536380                0.351034           6.536380            1       True         25
# 21          XGBoost_r194_BAG_L1   0.816289    accuracy       0.129058    3.641982                0.129058           3.641982            1       True         33
# 22          LightGBM_r15_BAG_L1   0.816059    accuracy       0.185948    3.041536                0.185948           3.041536            1       True         48
# 23   NeuralNetFastAI_r95_BAG_L1   0.815254    accuracy       0.488201   63.834656                0.488201          63.834656            1       True         45
# 24   NeuralNetFastAI_r11_BAG_L1   0.815024    accuracy       0.926801   93.901902                0.926801          93.901902            1       True         32
# 25  NeuralNetFastAI_r145_BAG_L1   0.814794    accuracy       0.747312   75.451607                0.747312          75.451607            1       True         26
# 26          LightGBM_r96_BAG_L1   0.814333    accuracy       0.466827    6.544591                0.466827           6.544591            1       True         17
# 27           XGBoost_r33_BAG_L1   0.813068    accuracy       0.851582    7.408378                0.851582           7.408378            1       True         19
# 28         LightGBMLarge_BAG_L1   0.812953    accuracy       0.143607    5.810352                0.143607           5.810352            1       True         11
# 29         LightGBM_r161_BAG_L1   0.811803    accuracy       0.214476   10.030959                0.214476          10.030959            1       True         38
# 30         LightGBM_r196_BAG_L1   0.811688    accuracy       0.691876   13.476882                0.691876          13.476882            1       True         42
# 31           XGBoost_r98_BAG_L1   0.811112    accuracy       0.200826    6.087744                0.200826           6.087744            1       True         47
# 32          CatBoost_r86_BAG_L1   0.810767    accuracy       0.091927   19.581218                0.091927          19.581218            1       True         50
# 33       ExtraTrees_r172_BAG_L1   0.809387    accuracy       0.465396    1.925775                0.465396           1.925775            1       True         34
# 34  NeuralNetFastAI_r143_BAG_L1   0.807776    accuracy       0.250280   30.687684                0.250280          30.687684            1       True         39
# 35  NeuralNetFastAI_r156_BAG_L1   0.807201    accuracy       0.249479   28.759064                0.249479          28.759064            1       True         41
# 36    NeuralNetTorch_r41_BAG_L1   0.806051    accuracy       0.168416   85.494987                0.168416          85.494987            1       True         46
# 37    NeuralNetTorch_r22_BAG_L1   0.805476    accuracy       0.296606  153.354795                0.296606         153.354795            1       True         18
# 38    NeuralNetTorch_r30_BAG_L1   0.805476    accuracy       0.429319  268.450722                0.429319         268.450722            1       True         28
# 39        ExtraTrees_r42_BAG_L1   0.804670    accuracy       0.374198    1.019114                0.374198           1.019114            1       True         20
# 40        ExtraTreesEntr_BAG_L1   0.803980    accuracy       0.457521    1.009423                0.457521           1.009423            1       True          7
# 41      RandomForestGini_BAG_L1   0.803865    accuracy       0.417642    1.559378                0.417642           1.559378            1       True          3
# 42      RandomForest_r39_BAG_L1   0.803405    accuracy       0.380268    2.134588                0.380268           2.134588            1       True         43
# 43        NeuralNetTorch_BAG_L1   0.802830    accuracy       0.251242   86.325169                0.251242          86.325169            1       True         10
# 44    NeuralNetTorch_r86_BAG_L1   0.802600    accuracy       0.503969  300.668324                0.503969         300.668324            1       True         30
# 45     RandomForest_r195_BAG_L1   0.802370    accuracy       0.453059    2.387301                0.453059           2.387301            1       True         24
# 46    NeuralNetTorch_r79_BAG_L1   0.801795    accuracy       0.252529  122.968440                0.252529         122.968440            1       True         13
# 47        ExtraTreesGini_BAG_L1   0.801795    accuracy       0.538740    1.193713                0.538740           1.193713            1       True          6
# 48      RandomForestEntr_BAG_L1   0.800989    accuracy       0.429334    1.427815                0.429334           1.427815            1       True          4
# 49   NeuralNetTorch_r158_BAG_L1   0.793512    accuracy       0.344876  118.410551                0.344876         118.410551            1       True         49
# 50    NeuralNetTorch_r14_BAG_L1   0.786035    accuracy       0.219782   99.001686                0.219782          99.001686            1       True         37
# Number of models trained: 51
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XGBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 5 | ['HomePlanet', 'Destination', 'AgeGroup', 'Deck', 'Side']
# ('float', [])     : 9 | ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', ...]
# ('int', [])       : 1 | ['GroupSize']
# ('int', ['bool']) : 2 | ['CryoSleep', 'VIP']
# *** End of fit() summary ***
# {'model_types': {'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB', 'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB', 'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF', 'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF', 'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost', 'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT', 'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost', 'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB', 'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost', 'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost', 'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT', 'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost', 'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF', 'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost', 'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost', 'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT', 'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB', 'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF', 'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost', 'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost', 'WeightedEnsemble_L2': 'WeightedEnsembleModel'}, 'model_performance': {'LightGBMXT_BAG_L1': 0.8200851259634189, 'LightGBM_BAG_L1': 0.8170942137351892, 'RandomForestGini_BAG_L1': 0.8038651788795582, 'RandomForestEntr_BAG_L1': 0.8009893017370298, 'CatBoost_BAG_L1': 0.822730932934545, 'ExtraTreesGini_BAG_L1': 0.8017945473369378, 'ExtraTreesEntr_BAG_L1': 0.8039802139652594, 'NeuralNetFastAI_BAG_L1': 0.82020016104912, 'XGBoost_BAG_L1': 0.818589669849304, 'NeuralNetTorch_BAG_L1': 0.802829863108248, 'LightGBMLarge_BAG_L1': 0.8129529506499482, 'CatBoost_r177_BAG_L1': 0.8242263890486599, 'NeuralNetTorch_r79_BAG_L1': 0.8017945473369378, 'LightGBM_r131_BAG_L1': 0.8181295295064995, 'NeuralNetFastAI_r191_BAG_L1': 0.8173242839065915, 'CatBoost_r9_BAG_L1': 0.8220407224203382, 'LightGBM_r96_BAG_L1': 0.814333371678362, 'NeuralNetTorch_r22_BAG_L1': 0.8054756700793743, 'XGBoost_r33_BAG_L1': 0.8130679857356494, 'ExtraTrees_r42_BAG_L1': 0.8046704244794662, 'CatBoost_r137_BAG_L1': 0.8187047049350051, ...
# 0          CatBoost_r177_BAG_L1   0.824226    accuracy       0.061593
# 1           WeightedEnsemble_L2   0.824226    accuracy       0.062889
# 2          CatBoost_r167_BAG_L1   0.823306    accuracy       0.057932
# 3               CatBoost_BAG_L1   0.822731    accuracy       0.071264
# 4           CatBoost_r69_BAG_L1   0.822731    accuracy       0.086545
# 5            CatBoost_r9_BAG_L1   0.822041    accuracy       0.078792
# 6           CatBoost_r13_BAG_L1   0.821351    accuracy       0.062963
# 7        NeuralNetFastAI_BAG_L1   0.820200    accuracy       0.310112
# 8             LightGBMXT_BAG_L1   0.820085    accuracy       0.242966
# 9           CatBoost_r70_BAG_L1   0.819165    accuracy       0.109517
# 10          CatBoost_r50_BAG_L1   0.819050    accuracy       0.082145
# 11         CatBoost_r137_BAG_L1   0.818705    accuracy       0.067892
# 12               XGBoost_BAG_L1   0.818590    accuracy       0.858043
# 13  NeuralNetFastAI_r103_BAG_L1   0.818475    accuracy       0.427210
# 14           XGBoost_r89_BAG_L1   0.818475    accuracy       1.096445
# 15         LightGBM_r131_BAG_L1   0.818130    accuracy       0.463163
# 16         LightGBM_r130_BAG_L1   0.817439    accuracy       0.113697
# 17  NeuralNetFastAI_r191_BAG_L1   0.817324    accuracy       0.585307
# 18              LightGBM_BAG_L1   0.817094    accuracy       0.174728
# 19  NeuralNetFastAI_r102_BAG_L1   0.816979    accuracy       0.331258
# 20         LightGBM_r188_BAG_L1   0.816979    accuracy       0.351034
# 21          XGBoost_r194_BAG_L1   0.816289    accuracy       0.129058
# 22          LightGBM_r15_BAG_L1   0.816059    accuracy       0.185948
# 23   NeuralNetFastAI_r95_BAG_L1   0.815254    accuracy       0.488201
# 24   NeuralNetFastAI_r11_BAG_L1   0.815024    accuracy       0.926801
# 25  NeuralNetFastAI_r145_BAG_L1   0.814794    accuracy       0.747312
# 26          LightGBM_r96_BAG_L1   0.814333    accuracy       0.466827
# 27           XGBoost_r33_BAG_L1   0.813068    accuracy       0.851582
# 28         LightGBMLarge_BAG_L1   0.812953    accuracy       0.143607
# 29         LightGBM_r161_BAG_L1   0.811803    accuracy       0.214476
# 30         LightGBM_r196_BAG_L1   0.811688    accuracy       0.691876
# 31           XGBoost_r98_BAG_L1   0.811112    accuracy       0.200826
# 32          CatBoost_r86_BAG_L1   0.810767    accuracy       0.091927
# 33       ExtraTrees_r172_BAG_L1   0.809387    accuracy       0.465396
# 34  NeuralNetFastAI_r143_BAG_L1   0.807776    accuracy       0.250280
# 35  NeuralNetFastAI_r156_BAG_L1   0.807201    accuracy       0.249479
# 36    NeuralNetTorch_r41_BAG_L1   0.806051    accuracy       0.168416
# 37    NeuralNetTorch_r22_BAG_L1   0.805476    accuracy       0.296606
# 38    NeuralNetTorch_r30_BAG_L1   0.805476    accuracy       0.429319
# 39        ExtraTrees_r42_BAG_L1   0.804670    accuracy       0.374198
# 40        ExtraTreesEntr_BAG_L1   0.803980    accuracy       0.457521
# 41      RandomForestGini_BAG_L1   0.803865    accuracy       0.417642
# 42      RandomForest_r39_BAG_L1   0.803405    accuracy       0.380268
# 43        NeuralNetTorch_BAG_L1   0.802830    accuracy       0.251242
# 44    NeuralNetTorch_r86_BAG_L1   0.802600    accuracy       0.503969
# 45     RandomForest_r195_BAG_L1   0.802370    accuracy       0.453059
# 46    NeuralNetTorch_r79_BAG_L1   0.801795    accuracy       0.252529
# 47        ExtraTreesGini_BAG_L1   0.801795    accuracy       0.538740
# 48      RandomForestEntr_BAG_L1   0.800989    accuracy       0.429334
# 49   NeuralNetTorch_r158_BAG_L1   0.793512    accuracy       0.344876
# 50    NeuralNetTorch_r14_BAG_L1   0.786035    accuracy       0.219782
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0    12.714505                0.061593          12.714505            1
# 1    13.065895                0.001296           0.351390            2
# 2    73.957142                0.057932          73.957142            1
# 3    71.294309                0.071264          71.294309            1
# 4    82.277463                0.086545          82.277463            1
# 5    85.204605                0.078792          85.204605            1
# 6    35.949803                0.062963          35.949803            1
# 7    36.078061                0.310112          36.078061            1
# 8     4.557313                0.242966           4.557313            1
# 9    71.328536                0.109517          71.328536            1
# 10   49.268504                0.082145          49.268504            1
# 11   52.001052                0.067892          52.001052            1
# 12    3.940618                0.858043           3.940618            1
# 13   71.147629                0.427210          71.147629            1
# 14    4.615076                1.096445           4.615076            1
# 15    6.875027                0.463163           6.875027            1
# 16    3.309726                0.113697           3.309726            1
# 17  107.532897                0.585307         107.532897            1
# 18    4.536127                0.174728           4.536127            1
# 19   24.904967                0.331258          24.904967            1
# 20    6.536380                0.351034           6.536380            1
# 21    3.641982                0.129058           3.641982            1
# 22    3.041536                0.185948           3.041536            1
# 23   63.834656                0.488201          63.834656            1
# 24   93.901902                0.926801          93.901902            1
# 25   75.451607                0.747312          75.451607            1
# 26    6.544591                0.466827           6.544591            1
# 27    7.408378                0.851582           7.408378            1
# 28    5.810352                0.143607           5.810352            1
# 29   10.030959                0.214476          10.030959            1
# 30   13.476882                0.691876          13.476882            1
# 31    6.087744                0.200826           6.087744            1
# 32   19.581218                0.091927          19.581218            1
# 33    1.925775                0.465396           1.925775            1
# 34   30.687684                0.250280          30.687684            1
# 35   28.759064                0.249479          28.759064            1
# 36   85.494987                0.168416          85.494987            1
# 37  153.354795                0.296606         153.354795            1
# 38  268.450722                0.429319         268.450722            1
# 39    1.019114                0.374198           1.019114            1
# 40    1.009423                0.457521           1.009423            1
# 41    1.559378                0.417642           1.559378            1
# 42    2.134588                0.380268           2.134588            1
# 43   86.325169                0.251242          86.325169            1
# 44  300.668324                0.503969         300.668324            1
# 45    2.387301                0.453059           2.387301            1
# 46  122.968440                0.252529         122.968440            1
# 47    1.193713                0.538740           1.193713            1
# 48    1.427815                0.429334           1.427815            1
# 49  118.410551                0.344876         118.410551            1
# 50   99.001686                0.219782          99.001686            1
#
#     can_infer  fit_order
# 0        True         12
# 1        True         51
# 2        True         44
# 3        True          5
# 4        True         35
# 5        True         16
# 6        True         23
# 7        True          8
# 8        True          1
# 9        True         40
# 10       True         31
# 11       True         21
# 12       True          9
# 13       True         36
# 14       True         27
# 15       True         14
# 16       True         29
# 17       True         15
# 18       True          2
# 19       True         22
# 20       True         25
# 21       True         33
# 22       True         48
# 23       True         45
# 24       True         32
# 25       True         26
# 26       True         17
# 27       True         19
# 28       True         11
# 29       True         38
# 30       True         42
# 31       True         47
# 32       True         50
# 33       True         34
# 34       True         39
# 35       True         41
# 36       True         46
# 37       True         18
# 38       True         28
# 39       True         20
# 40       True          7
# 41       True          3
# 42       True         43
# 43       True         10
# 44       True         30
# 45       True         24
# 46       True         13
# 47       True          6
# 48       True          4
# 49       True         49
# 50       True         37  }
# c:\Users\User\miniconda3\envs\DS\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ## 5. 예측 및 제출 파일 생성
# 학습된 모델을 사용하여 최종 예측을 수행하고, 캐글 제출 양식에 맞는 submission.csv 파일을 생성합니다

# %% [markdown]
# CatBoost를 단일 알고리즘으로 사용 : 0.8227점, 케글 점수 : 0.81038점

# %%
print("Generating predictions...")
# 예측 수행
y_pred = predictor.predict(test_final)

# 제출용 데이터프레임 생성 (인덱스 꼬임 방지를 위해 .values 사용)
submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'].values, 
    'Transported': y_pred.values 
})

# 데이터 타입 보정 (True/False 형태인지 확인)
submission['Transported'] = submission['Transported'].astype(bool)

# 저장 폴더 확인 및 저장
if not os.path.exists('submission'):
    os.makedirs('submission')

submission.to_csv(SUBMISSION_PATH, index=False)

print(f"Submission saved successfully to {SUBMISSION_PATH}")
print("\n=== [제출 파일 상단 5행 확인] ===")
print(submission.head())
# Out:
# Generating predictions...
# Submission saved successfully to submission/submission_optimized.csv
#
# === [제출 파일 상단 5행 확인] ===
#   PassengerId  Transported
# 0     0013_01         True
# 1     0018_01        False
# 2     0019_01         True
# 3     0021_01         True
# 4     0023_01        False

# %% [markdown]
# excluded_model_types=[]로 모든 모델 사용 : 0.8242점, 케글 점수 : 0.81084점

# %%
# 파일 저장 경로 설정
SUBMISSION_DIR = 'submission'
SUBMISSION_PATH = os.path.join(SUBMISSION_DIR, 'submission_v1.csv')

# 저장 폴더가 없으면 생성
if not os.path.exists(SUBMISSION_DIR):
    os.makedirs(SUBMISSION_DIR)
    print(f"Directory '{SUBMISSION_DIR}' created.")

print("Generating predictions for Kaggle...")

y_pred = predictor.predict(test_final)

submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'].values, 
    'Transported': y_pred.values 
})

# 캐글 요구 형식(True/False)으로 데이터 타입 보정
submission['Transported'] = submission['Transported'].astype(bool)

# CSV 파일로 저장
submission.to_csv(SUBMISSION_PATH, index=False)

print(f"\n✅ 제출 파일이 성공적으로 저장되었습니다")
print(f"경로: {SUBMISSION_PATH}")
print("-" * 30)
print("=== [제출 파일 상단 5행 확인] ===")
print(submission.head())
# Out:
# Generating predictions for Kaggle...
#
# ✅ 제출 파일이 성공적으로 저장되었습니다
# 경로: submission\submission_v1.csv
# ------------------------------
# === [제출 파일 상단 5행 확인] ===
#   PassengerId  Transported
# 0     0013_01         True
# 1     0018_01        False
# 2     0019_01         True
# 3     0021_01         True
# 4     0023_01        False
